# %%
import requests
import numpy as np
import pandas as pd
import io
import plotly.express as px
import plotly.graph_objects as go
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn import preprocessing
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.io as pio
import plotly.offline
from IPython.display import display
from IPython.display import IFrame

# %%
pio.templates.default = "plotly_dark"

# %%
#%%shell
#jupyter nbconvert --to latex /DIX.ipynb

# %%
data = requests.get('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=SPY&outputsize=full&apikey=').json()

# %%
open_df       = pd.DataFrame.from_dict(data['Time Series (Daily)']).T
open_df.index = pd.to_datetime(open_df.index)
open_df       = open_df.apply(pd.to_numeric, errors='coerce')
open_df.rename(columns={'1. open':'open'}, inplace=True)
open_df = open_df['open']
open_df = open_df.shift(1)

# %%
sm_data = requests.get('https://squeezemetrics.com/monitor/static/DIX.csv')

# %%
sm_df = pd.read_csv(io.BytesIO(sm_data.content), encoding='utf-8')  
sm_df.set_index(['date'], inplace=True)
sm_df = sm_df.apply(pd.to_numeric, errors='coerce')
sm_df.index = pd.to_datetime(sm_df.index)
sm_df.drop(['price'], axis=1, inplace=True)

# %%
vix_data = requests.get('http://www.cboe.com/publish/scheduledtask/mktdata/datahouse/vixcurrent.csv')

# %%
vix_df = pd.read_csv(io.BytesIO(vix_data.content), encoding='utf-8')  
vix_df.columns = vix_df.iloc[0]
vix_df.drop(vix_df.index[0], inplace=True)
vix_df['Date'] = pd.to_datetime(vix_df['Date'], format='%m/%d/%Y')
vix_df.set_index(['Date'], inplace=True)
vix_df = vix_df.apply(pd.to_numeric, errors='coerce')
vix_df.rename(columns={"VIX Close": "vix"}, inplace=True)
vix_df['vix_change'] = vix_df['vix'].pct_change(1)

# %%
df = pd.concat((sm_df, open_df, vix_df[['vix', 'vix_change']]), axis=1, join='inner')

periods = [1, 5, 10, 15, 30, 50, 100]

for p in periods:
    df[ str(p) + 'd_return'] = df['open'].pct_change(p).shift(periods=-p)

# %%
df
# Out:
#                  dix           gex    open    vix  vix_change  1d_return  \
# 2011-05-02  0.378842  1.897313e+09  135.96  15.99    0.084068  -0.002133
# 2011-05-03  0.383411  1.859731e+09  135.67  16.70    0.044403  -0.011720
# 2011-05-04  0.392122  1.717764e+09  134.08  17.08    0.022754   0.006414
# 2011-05-05  0.405457  1.361864e+09  134.94  18.20    0.065574  -0.005558
# 2011-05-06  0.418649  1.490329e+09  134.19  18.40    0.010989   0.007303
# ...              ...           ...     ...    ...         ...        ...
# 2020-11-16  0.414971  5.568672e+09  359.97  22.45   -0.028139   0.002611
# 2020-11-17  0.440556  5.804662e+09  360.91  22.71    0.011581  -0.014713
# 2020-11-18  0.416999  3.498179e+09  355.60  23.84    0.049758   0.005343
# 2020-11-19  0.438597  5.497968e+09  357.50  23.11   -0.030621   0.000000
# 2020-11-20  0.438085  2.325158e+09     NaN  23.70    0.025530        NaN
#
#             5d_return  10d_return  15d_return  30d_return  50d_return  \
# 2011-05-02  -0.005811   -0.024051   -0.025890   -0.056781   -0.027876
# 2011-05-03   0.000000   -0.017911   -0.031326   -0.063463   -0.029557
# 2011-05-04   0.000000    0.005370   -0.015289   -0.045868   -0.022375
# 2011-05-05   0.001556   -0.004521   -0.011635   -0.061657   -0.026679
# 2011-05-06  -0.004695   -0.016469    0.004322   -0.043446   -0.008346
# ...               ...         ...         ...         ...         ...
# 2020-11-16        NaN         NaN         NaN         NaN         NaN
# 2020-11-17        NaN         NaN         NaN         NaN         NaN
# 2020-11-18        NaN         NaN         NaN         NaN         NaN
# 2020-11-19        NaN         NaN         NaN         NaN         NaN
# 2020-11-20        NaN         NaN         NaN         NaN         NaN
#
#             100d_return
# 2011-05-02    -0.175419
# 2011-05-03    -0.155230
# 2011-05-04    -0.115976
# 2011-05-05    -0.127168
# 2011-05-06    -0.127729
# ...                 ...
# 2020-11-16          NaN
# 2020-11-17          NaN
# 2020-11-18          NaN
# 2020-11-19          NaN
# 2020-11-20          NaN
#
# [2408 rows x 12 columns]

# %%
colors =[[
'#00bfff',
'#00abe5',
'#0098cc',
'#0085b2',
'#007299',
'#005f7f',
'#004c66',
'#00394c',
'#002633',
'#001319',
'#000000'
],
[
'#ff0074',
'#e50068',
'#cc005c',
'#b20051',
'#990045',
'#7f003a',
'#66002e',
'#4c0022',
'#330017',
'#19000b',
'#000000',
]]

# %%
fig = px.histogram(df, x='dix', y=df.columns[5:], nbins=50, histfunc='avg',color_discrete_sequence=colors[1], barmode='overlay', title="DIX return histogram")
fig.update_layout(
    hovermode="x"
    )
#fig.show()
#pio.write_html(fig, file='fig1.html', auto_open=True)
IFrame(src='./fig1.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./fig1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
fig = px.histogram(df, x='gex', y=df.columns[5:], nbins=50, histfunc='avg', color_discrete_sequence=colors[0], barmode='overlay', title="GEX return histogram")
fig.update_layout(
    hovermode="x"
    )
#fig.show()
#pio.write_html(fig, file='fig2.html', auto_open=True)
IFrame(src='./fig2.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./fig2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
def df_to_plotly(df):
    return {'z': df.corr().values.tolist(),
            'x': df.corr().columns.tolist(),
            'y': df.corr().index.tolist()}

fig = go.Figure(data=go.Heatmap(df_to_plotly(df), colorscale=['#4900ff', '#ff0074']))
fig.update_layout(
    title="DIX & GEX correlation to returns",
    template="plotly_dark",
    hovermode="x"
    )
#fig.show()
#pio.write_html(fig, file='fig3.html', auto_open=True)
IFrame(src='./fig3.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./fig3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
""" We want to know if the DIX was above the threshold at any point during the n prior days.
    Returns: 1 if DIX > threshold during prior n days, else 0.
"""

thresholds = [0.35, 0.40, 0.45, 0.5]
forward_df = pd.DataFrame()

def n_prior(x, t):
    result = False
    for i in x:
        if i > t:
            result = True
    return result

for p in periods:
    for t in thresholds:
        forward_df[str(p) + 'd_prior_' + 'abv' + str(int(t*100))] = df['dix'].rolling(p).apply(lambda x: n_prior(x, t))

forward_df.head()
# Out:
#             1d_prior_abv35  1d_prior_abv40  1d_prior_abv45  1d_prior_abv50  \
# 2011-05-02             1.0             0.0             0.0             0.0
# 2011-05-03             1.0             0.0             0.0             0.0
# 2011-05-04             1.0             0.0             0.0             0.0
# 2011-05-05             1.0             1.0             0.0             0.0
# 2011-05-06             1.0             1.0             0.0             0.0
#
#             5d_prior_abv35  5d_prior_abv40  5d_prior_abv45  5d_prior_abv50  \
# 2011-05-02             NaN             NaN             NaN             NaN
# 2011-05-03             NaN             NaN             NaN             NaN
# 2011-05-04             NaN             NaN             NaN             NaN
# 2011-05-05             NaN             NaN             NaN             NaN
# 2011-05-06             1.0             1.0             0.0             0.0
#
#             10d_prior_abv35  10d_prior_abv40  ...  30d_prior_abv45  \
# 2011-05-02              NaN              NaN  ...              NaN
# 2011-05-03              NaN              NaN  ...              NaN
# 2011-05-04              NaN              NaN  ...              NaN
# 2011-05-05              NaN              NaN  ...              NaN
# 2011-05-06              NaN              NaN  ...              NaN
#
#             30d_prior_abv50  50d_prior_abv35  50d_prior_abv40  \
# 2011-05-02              NaN              NaN              NaN
# 2011-05-03              NaN              NaN              NaN
# 2011-05-04              NaN              NaN              NaN
# 2011-05-05              NaN              NaN              NaN
# 2011-05-06              NaN              NaN              NaN
#
#             50d_prior_abv45  50d_prior_abv50  100d_prior_abv35  \
# 2011-05-02              NaN              NaN               NaN
# 2011-05-03              NaN              NaN               NaN
# 2011-05-04              NaN              NaN               NaN
# 2011-05-05              NaN              NaN               NaN
# 2011-05-06              NaN              NaN               NaN
#
#             100d_prior_abv40  100d_prior_abv45  100d_prior_abv50
# 2011-05-02               NaN               NaN               NaN
# 2011-05-03               NaN               NaN               NaN
# 2011-05-04               NaN               NaN               NaN
# 2011-05-05               NaN               NaN               NaN
# 2011-05-06               NaN               NaN               NaN
#
# [5 rows x 28 columns]

# %%
""" If DIX was above the threshold, we include the return in the cumulative return"""

forward_return_df = pd.DataFrame()

for p in periods:
    for t in thresholds:
        forward_return_df[str(p) + 'd_cumprod_' + 'abv' + str(int(t * 100))] = (df[forward_df[str(p) + 'd_prior_' + 'abv' + str(int(t*100))] == 1]['1d_return'] + 1).cumprod()

forward_return_df.ffill(axis=0, inplace=True)
forward_return_df.tail()
# Out:
#             1d_cumprod_abv35  1d_cumprod_abv40  1d_cumprod_abv45  \
# 2020-11-16          2.682978          3.090612           1.91497
# 2020-11-17          2.643504          3.045141           1.91497
# 2020-11-18          2.657628          3.061411           1.91497
# 2020-11-19          2.657628          3.061411           1.91497
# 2020-11-20          2.657628          3.061411           1.91497
#
#             1d_cumprod_abv50  5d_cumprod_abv35  5d_cumprod_abv40  \
# 2020-11-16          1.150855          2.689545          2.720898
# 2020-11-17          1.150855          2.649974          2.680866
# 2020-11-18          1.150855          2.664133          2.695190
# 2020-11-19          1.150855          2.664133          2.695190
# 2020-11-20          1.150855          2.664133          2.695190
#
#             5d_cumprod_abv45  5d_cumprod_abv50  10d_cumprod_abv35  \
# 2020-11-16          2.190798          1.159729           2.702231
# 2020-11-17          2.190798          1.159729           2.662474
# 2020-11-18          2.190798          1.159729           2.676700
# 2020-11-19          2.190798          1.159729           2.676700
# 2020-11-20          2.190798          1.159729           2.676700
#
#             10d_cumprod_abv40  ...  30d_cumprod_abv45  30d_cumprod_abv50  \
# 2020-11-16           2.591416  ...           2.920335           1.496496
# 2020-11-17           2.553289  ...           2.920335           1.496496
# 2020-11-18           2.566932  ...           2.920335           1.496496
# 2020-11-19           2.566932  ...           2.920335           1.496496
# 2020-11-20           2.566932  ...           2.920335           1.496496
#
#             50d_cumprod_abv35  50d_cumprod_abv40  50d_cumprod_abv45  \
# 2020-11-16           2.732304           2.877213           2.673959
# 2020-11-17           2.692104           2.834881           2.673959
# 2020-11-18           2.706488           2.850028           2.673959
# 2020-11-19           2.706488           2.850028           2.673959
# 2020-11-20           2.706488           2.850028           2.673959
#
#             50d_cumprod_abv50  100d_cumprod_abv35  100d_cumprod_abv40  \
# 2020-11-16           1.555723            3.186843            3.186843
# 2020-11-17           1.555723            3.139956            3.139956
# 2020-11-18           1.555723            3.156733            3.156733
# 2020-11-19           1.555723            3.156733            3.156733
# 2020-11-20           1.555723            3.156733            3.156733
#
#             100d_cumprod_abv45  100d_cumprod_abv50
# 2020-11-16            2.752262            1.634526
# 2020-11-17            2.711769            1.634526
# 2020-11-18            2.726258            1.634526
# 2020-11-19            2.726258            1.634526
# 2020-11-20            2.726258            1.634526
#
# [5 rows x 28 columns]

# %%
def make_return_plot(forward_return_df, df, thresholds, p):

    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index, y=(df['1d_return'] + 1).cumprod(),
                        mode='lines',
                        name='S&P500 return',
                        line=dict(color='#8900ff', width=2)
                        ))

    i = 2
    for t in thresholds:
        fig.add_trace(go.Scatter(x=forward_return_df.index, y=forward_return_df[str(p) + 'd_cumprod_' + 'abv' + str(int(t * 100))],
                            mode='lines',
                            name='DIX above ' + str(int(t * 100)),
                            line=dict(color=colors[0][i], width=2)
                            ))
        i+=2


    fig.update_layout(
    title=str(p) + 'd_holding',
    yaxis_title="Cumulative returns",
    hovermode="x"
    )
    #fig.show()
    #pio.write_html(fig, file='plot' + str(p) + '.html', auto_open=True)

# %%
    for p in periods:
      make_return_plot(forward_return_df, df, thresholds, p)

# %%
IFrame(src='./plot1.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot10.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot10.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot30.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot30.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot50.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot50.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot100.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot100.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# **Let's create a Random Forest Classifier**

# %%
rfc_data = np.array(df.dropna())

train_l = int(rfc_data.shape[0] * 0.3)

def quantiles(x):
  return pd.qcut(x, 10, labels=False)

features = np.hstack((rfc_data[:, 0:2], rfc_data[:, 4, np.newaxis]))
#features = rfc_data[:, 0:2]
labels = np.apply_along_axis(quantiles, 0, rfc_data[:, 5:])

X_train, X_test, y_train, y_test = features[0:train_l], features[train_l:], labels[0:train_l], labels[train_l:]

rfc = RandomForestClassifier(n_estimators=200, random_state=42, max_leaf_nodes=10, min_impurity_split=0.05)
multi_target_forest = MultiOutputClassifier(rfc, n_jobs=-1)
multi_target_forest.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(max_leaf_nodes=10,
#                                                        min_impurity_split=0.05,
#                                                        n_estimators=200,
#                                                        random_state=42),
#                       n_jobs=-1)

# %%
pred = multi_target_forest.predict(X_test)

# %%
print(pred.shape)
print(pred)
# Out:
# (1616, 7)
# [[8 9 9 ... 8 0 8]
#  [9 9 9 ... 9 9 9]
#  [8 9 9 ... 8 0 8]
#  ...
#  [9 9 9 ... 9 8 9]
#  [2 8 7 ... 1 1 4]
#  [1 2 6 ... 1 1 2]]

# %%
idx = df.dropna().index[train_l:]
columns = [str(p) + 'd' for p in periods]
rfc_df = pd.DataFrame(pred, columns=columns, index=idx)

q_thresholds = [5, 6, 7, 8, 9]

pred_df = pd.DataFrame(pred)
forward_rfc_df = pd.DataFrame()

def n_prior(x, q):
    result = False
    for i in x:
        if i >= q:
            result = True
    return result


for p in range(len(periods)):
    for q in q_thresholds:
        forward_rfc_df[str(periods[p]) + 'd_prior_' + 'abv' + str(q)] = pred_df.iloc[:, p].rolling(periods[p]).apply(lambda x: n_prior(x, q))


forward_rfc_df.set_index(idx, inplace=True)
forward_rfc_df
# Out:
#             1d_prior_abv5  1d_prior_abv6  1d_prior_abv7  1d_prior_abv8  \
# 2014-01-31            1.0            1.0            1.0            1.0
# 2014-02-03            1.0            1.0            1.0            1.0
# 2014-02-04            1.0            1.0            1.0            1.0
# 2014-02-05            1.0            1.0            1.0            1.0
# 2014-02-06            1.0            1.0            1.0            1.0
# ...                   ...            ...            ...            ...
# 2020-06-25            1.0            1.0            1.0            1.0
# 2020-06-26            1.0            1.0            1.0            1.0
# 2020-06-29            1.0            1.0            1.0            1.0
# 2020-06-30            0.0            0.0            0.0            0.0
# 2020-07-01            0.0            0.0            0.0            0.0
#
#             1d_prior_abv9  5d_prior_abv5  5d_prior_abv6  5d_prior_abv7  \
# 2014-01-31            0.0            NaN            NaN            NaN
# 2014-02-03            1.0            NaN            NaN            NaN
# 2014-02-04            0.0            NaN            NaN            NaN
# 2014-02-05            0.0            NaN            NaN            NaN
# 2014-02-06            0.0            1.0            1.0            1.0
# ...                   ...            ...            ...            ...
# 2020-06-25            1.0            1.0            1.0            1.0
# 2020-06-26            1.0            1.0            1.0            1.0
# 2020-06-29            1.0            1.0            1.0            1.0
# 2020-06-30            0.0            1.0            1.0            1.0
# 2020-07-01            0.0            1.0            1.0            1.0
#
#             5d_prior_abv8  5d_prior_abv9  ...  50d_prior_abv5  50d_prior_abv6  \
# 2014-01-31            NaN            NaN  ...             NaN             NaN
# 2014-02-03            NaN            NaN  ...             NaN             NaN
# 2014-02-04            NaN            NaN  ...             NaN             NaN
# 2014-02-05            NaN            NaN  ...             NaN             NaN
# 2014-02-06            1.0            1.0  ...             NaN             NaN
# ...                   ...            ...  ...             ...             ...
# 2020-06-25            1.0            1.0  ...             1.0             1.0
# 2020-06-26            1.0            1.0  ...             1.0             1.0
# 2020-06-29            1.0            1.0  ...             1.0             1.0
# 2020-06-30            1.0            1.0  ...             1.0             1.0
# 2020-07-01            1.0            1.0  ...             1.0             1.0
#
#             50d_prior_abv7  50d_prior_abv8  50d_prior_abv9  100d_prior_abv5  \
# 2014-01-31             NaN             NaN             NaN              NaN
# 2014-02-03             NaN             NaN             NaN              NaN
# 2014-02-04             NaN             NaN             NaN              NaN
# 2014-02-05             NaN             NaN             NaN              NaN
# 2014-02-06             NaN             NaN             NaN              NaN
# ...                    ...             ...             ...              ...
# 2020-06-25             1.0             1.0             1.0              1.0
# 2020-06-26             1.0             1.0             1.0              1.0
# 2020-06-29             1.0             1.0             1.0              1.0
# 2020-06-30             1.0             1.0             1.0              1.0
# 2020-07-01             1.0             1.0             1.0              1.0
#
#             100d_prior_abv6  100d_prior_abv7  100d_prior_abv8  100d_prior_abv9
# 2014-01-31              NaN              NaN              NaN              NaN
# 2014-02-03              NaN              NaN              NaN              NaN
# 2014-02-04              NaN              NaN              NaN              NaN
# 2014-02-05              NaN              NaN              NaN              NaN
# 2014-02-06              NaN              NaN              NaN              NaN
# ...                     ...              ...              ...              ...
# 2020-06-25              1.0              1.0              1.0              1.0
# 2020-06-26              1.0              1.0              1.0              1.0
# 2020-06-29              1.0              1.0              1.0              1.0
# 2020-06-30              1.0              1.0              1.0              1.0
# 2020-07-01              1.0              1.0              1.0              1.0
#
# [1616 rows x 35 columns]

# %%
forward_rfc_return_df = pd.DataFrame()
df_cut = df.loc[forward_rfc_df.index]

for p in periods:
    for q in q_thresholds:
        forward_rfc_return_df[str(p) + 'd_cumprod_' + 'abv' + str(q)] = (df_cut[forward_rfc_df[str(p) + 'd_prior_' + 'abv' + str(q)] == 1]['1d_return'] + 1).cumprod()

forward_rfc_return_df.ffill(axis=0, inplace=True)
forward_rfc_return_df
# Out:
#             1d_cumprod_abv5  1d_cumprod_abv6  1d_cumprod_abv7  \
# 2014-01-31         0.983031         0.983031         0.983031
# 2014-02-03         0.982076         0.982076         0.982076
# 2014-02-04         0.986571         0.986571         0.986571
# 2014-02-05         1.001910         1.001910         1.001910
# 2014-02-06         1.009721         1.009721         1.009721
# ...                     ...              ...              ...
# 2020-06-23         1.748294         1.940843         1.838411
# 2020-06-24         1.763791         1.958047         1.854707
# 2020-06-25         1.736426         1.927668         1.825932
# 2020-06-26         1.751290         1.944168         1.841561
# 2020-06-29         1.783436         1.979855         1.875365
#
#             1d_cumprod_abv8  1d_cumprod_abv9  5d_cumprod_abv5  \
# 2014-01-31         0.983031              NaN              NaN
# 2014-02-03         0.982076         0.999028              NaN
# 2014-02-04         0.986571         0.999028              NaN
# 2014-02-05         1.001910         0.999028              NaN
# 2014-02-06         1.009721         0.999028         1.007795
# ...                     ...              ...              ...
# 2020-06-23         1.877831         1.617364         1.527653
# 2020-06-24         1.894476         1.631701         1.541194
# 2020-06-25         1.865084         1.606385         1.517283
# 2020-06-26         1.881049         1.620136         1.530270
# 2020-06-29         1.915577         1.649875         1.558360
#
#             5d_cumprod_abv6  5d_cumprod_abv7  5d_cumprod_abv8  \
# 2014-01-31              NaN              NaN              NaN
# 2014-02-03              NaN              NaN              NaN
# 2014-02-04              NaN              NaN              NaN
# 2014-02-05              NaN              NaN              NaN
# 2014-02-06         1.007795         1.007795         1.007795
# ...                     ...              ...              ...
# 2020-06-23         1.527653         1.392342         1.392342
# 2020-06-24         1.541194         1.404684         1.404684
# 2020-06-25         1.517283         1.382891         1.382891
# 2020-06-26         1.530270         1.394728         1.394728
# 2020-06-29         1.558360         1.420329         1.420329
#
#             5d_cumprod_abv9  ...  50d_cumprod_abv5  50d_cumprod_abv6  \
# 2014-01-31              NaN  ...               NaN               NaN
# 2014-02-03              NaN  ...               NaN               NaN
# 2014-02-04              NaN  ...               NaN               NaN
# 2014-02-05              NaN  ...               NaN               NaN
# 2014-02-06         1.007795  ...               NaN               NaN
# ...                     ...  ...               ...               ...
# 2020-06-23         1.482820  ...          1.664704          1.664704
# 2020-06-24         1.495963  ...          1.679460          1.679460
# 2020-06-25         1.472754  ...          1.653404          1.653404
# 2020-06-26         1.485360  ...          1.667556          1.667556
# 2020-06-29         1.512625  ...          1.698166          1.698166
#
#             50d_cumprod_abv7  50d_cumprod_abv8  50d_cumprod_abv9  \
# 2014-01-31               NaN               NaN               NaN
# 2014-02-03               NaN               NaN               NaN
# 2014-02-04               NaN               NaN               NaN
# 2014-02-05               NaN               NaN               NaN
# 2014-02-06               NaN               NaN               NaN
# ...                      ...               ...               ...
# 2020-06-23          1.602035          1.602035          1.734063
# 2020-06-24          1.616236          1.616236          1.749434
# 2020-06-25          1.591160          1.591160          1.722292
# 2020-06-26          1.604780          1.604780          1.737034
# 2020-06-29          1.634237          1.634237          1.768919
#
#             100d_cumprod_abv5  100d_cumprod_abv6  100d_cumprod_abv7  \
# 2014-01-31                NaN                NaN                NaN
# 2014-02-03                NaN                NaN                NaN
# 2014-02-04                NaN                NaN                NaN
# 2014-02-05                NaN                NaN                NaN
# 2014-02-06                NaN                NaN                NaN
# ...                       ...                ...                ...
# 2020-06-23           1.561943           1.561943           1.561943
# 2020-06-24           1.575789           1.575789           1.575789
# 2020-06-25           1.551341           1.551341           1.551341
# 2020-06-26           1.564620           1.564620           1.564620
# 2020-06-29           1.593340           1.593340           1.593340
#
#             100d_cumprod_abv8  100d_cumprod_abv9
# 2014-01-31                NaN                NaN
# 2014-02-03                NaN                NaN
# 2014-02-04                NaN                NaN
# 2014-02-05                NaN                NaN
# 2014-02-06                NaN                NaN
# ...                       ...                ...
# 2020-06-23           1.698946           1.566163
# 2020-06-24           1.714005           1.580045
# 2020-06-25           1.687413           1.555531
# 2020-06-26           1.701857           1.568846
# 2020-06-29           1.733096           1.597644
#
# [1086 rows x 35 columns]

# %%
def make_rfc_return_plot(forward_return_df, df, thresholds, p):

    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index, y=(df['1d_return'] + 1).cumprod(),
                        mode='lines',
                        name='S&P500 return',
                        line=dict(color='#8900ff', width=2)
                        ))

    i = 2
    for t in thresholds:
        fig.add_trace(go.Scatter(x=forward_return_df.index, y=forward_return_df[str(p) + 'd_cumprod_' + 'abv' + str(t)],
                            mode='lines',
                            name='DIX above ' + str(t),
                            line=dict(color=colors[0][i], width=2)
                            ))
        i+=1


    fig.update_layout(
    title=str(p) + 'd_holding',
    yaxis_title="Cumulative returns",
    hovermode="x"
    )
    #fig.show()
    #pio.write_html(fig, file='plot2' + str(p) + '.html', auto_open=True)

# %%
    for p in periods:
      make_rfc_return_plot(forward_rfc_return_df, df_cut, q_thresholds, p)

# %%
IFrame(src='./plot21.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot21.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot210.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot21.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot230.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot230.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot250.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot250.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(src='./plot2100.html', width=950, height=600)
# Out:
#         <iframe
#             width="950"
#             height="600"
#             src="./plot2100.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
